# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2

# %matplotlib inline 

import matplotlib
import matplotlib.pyplot as plt
import glob
from sklearn import model_selection
from Model.config import Config
import Model.utils
import Model.model as modellib
from Model import visualize
from Model.model import log


# Root directory of the project
# ROOT_DIR = os.getcwd()
ROOT_DIR = '/host'
os.chdir(ROOT_DIR)

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Path to COCO trained weights
# COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

MODEL_NIR_PATH = os.path.join(ROOT_DIR,"Weights/mask_rcnn_irises_ND.h5" )
MODEL_VIS_PATH = os.path.join(ROOT_DIR,"Weights/mask_rcnn_irises_Ubiris.h5" )
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class irisConfig(Config):
    
    
    # Give the configuration a recognizable name
    NAME = "irises"

    GPU_COUNT = 1
    IMAGES_PER_GPU = 2

    NUM_CLASSES = 1 + 1  # background + 3 shapes

    IMAGE_MIN_DIM = 640
    IMAGE_MAX_DIM = 640

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 1000

    VALIDATION_STEPS = 50
    


class InferenceConfig(irisConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()
inference_config.display()
model_nir = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

model_vis = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

#Loads weights from a static model file

print("Loading NIR model")
model_nir.load_weights(MODEL_NIR_PATH, by_name=True)

print("Loading VIS model")
model_vis.load_weights(MODEL_VIS_PATH, by_name=True)
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_MAX_DIM                  640
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  640
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [640 640   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           irises
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
#
#
# Loading NIR model
# Loading VIS model

# %%
import matplotlib.pyplot as plt
import os
import glob
import cv2
from sklearn import model_selection
import re
from scipy import ndimage
import skimage.io
from PIL import Image
import numpy as np
from skimage.io import imread
from skimage.color import gray2rgb
import time
from Model.visualize import display_images,display_weight_stats
import Model.utils as utils

class_names = ['BG','iris']

# Root directory of the project

# Load images from folder

numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

def find_tiff_files(directory):
    tiff_files = []
    
    # Walk through all the subdirectories and files
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.tiff') or file.lower().endswith('tif'):
#                 path = os.path.relpath(os.path.join(root, file), start=directory)
                path = os.path.join(root, file)
                
                tiff_files.append(path)
    
    return tiff_files


#Inference one at a time, change to batch (Memory per image calculate)
def runonFolder(imList,segmFolder,maskFolder,centered):
    
    
    print (  len(imList))
    print(imList)

    
    avgTime = 0.0
    
#     irisFolder = saveFolder
#     if not os.path.exists(irisFolder):
#         os.makedirs(irisFolder)
        
#     if not os.path.exists(maskFolder):
#         os.makedirs(maskFolder)
#     os.chdir(irisFolder)

    

    start = time.time()

    print ("Saving in " + os.getcwd())
    for i in range(len(imList)):
#     for i in range(5):

        try:
            im = imread(imList[i])
            image = skimage.color.gray2rgb(im)
            im, window, scale, padding, crop = utils.resize_image(
            image,
            min_dim=inference_config.IMAGE_MIN_DIM,
            min_scale=inference_config.IMAGE_MIN_SCALE,
            max_dim=inference_config.IMAGE_MAX_DIM,
            mode="pad64")

            if "NIR" in imList[i]:
                results = model_nir.detect([im], verbose=0)
    #             print("Using NIR model")
            else:
                results = model_vis.detect([im], verbose=0)
    #             print("Using VIS model")

            r = results[0]
            mask = r['masks'][:, :, 0]


            saveSubPath = os.path.join(*imList[i].split("/")[3:-1])
            saveName = imList[i].split("/")[-1]

            saveName = re.sub('[.].*','.png',saveName)

            print(saveName)

            mask = r['masks'][:, :, 0]
            bbox = r['rois'][0]
    #             print (bbox)


            # Processing with the centered option
            if centered:
                # Get the bounding box coordinates
                bbox = r['rois'][0]
                cx = ((bbox[0] + bbox[2]) // 2)
                cy = ((bbox[1] + bbox[3]) // 2)
                PADDING = 20

                # Crop the mask and the image based on the bounding box
                croppedMask = mask[bbox[0] - PADDING:bbox[2] + PADDING, bbox[1] - PADDING:bbox[3] + PADDING]
                croppedIm = im[bbox[0] - PADDING:bbox[2] + PADDING, bbox[1] - PADDING:bbox[3] + PADDING]

                # Perform bitwise AND between image and cropped mask to isolate the region
                tIm = croppedIm[:, :, 0]
                croppedMask = croppedMask * 255
                anded = np.bitwise_and(tIm, croppedMask)
    #             matplotlib.image.imsave(saveName, anded)


            if not centered:
                # If not centered, use the whole image and mask
                tIm = im[:, :, 0]
                mask = mask * 255
                anded = np.bitwise_and(tIm, mask)
    #             matplotlib.image.imsave(saveName, anded)


            segmPath = os.path.join(segmFolder, saveSubPath)
            os.makedirs(segmPath, exist_ok=True)            

    #         try:
            matplotlib.image.imsave(os.path.join(segmPath,saveName), anded)
    #         except Exception as e:
    #             print("Error saving " + saveName + ": " + str(e) )
    #             print(anded)


            # Process and save the mask image without displaying it
    #         saveName = re.sub('[.].*', '.png', saveName)

            # Commenting out the line that visualizes and displays the image
    #         visualize.display_instances(im, r['rois'], r['masks'], r['class_ids'], class_names, show_bbox=True, ax=get_ax())

            maskPath = os.path.join(maskFolder, saveSubPath)
            os.makedirs(maskPath, exist_ok=True)

            matplotlib.image.imsave(os.path.join(maskPath, saveName), mask)
        
        except Exception as e:
            with open('logfile.log', 'a') as log_file:
                log_file.write("Exception with file {}. occurred: {}\n".format(saveName, e))

    end = time.time()
    # Print the average processing time
    print("Average time per image: " + str((end-start)/ len(imList)))

#Folder containing iris images
folderPath = ROOT_DIR+"/b"


imList = find_tiff_files(folderPath)

#Segmented masks stored in /segmented
runonFolder(imList,ROOT_DIR+"/segmented",ROOT_DIR+"/masks",centered = 0)
# Out:
# 12540
# ['/host/b/008/L/NIR/008_L_NIR_4.tiff', '/host/b/008/L/NIR/008_L_NIR_6.tiff', '/host/b/008/L/NIR/008_L_NIR_8.tiff', '/host/b/008/L/NIR/008_L_NIR_2.tiff', '/host/b/008/L/NIR/008_L_NIR_14.tiff', '/host/b/008/L/NIR/008_L_NIR_3.tiff', '/host/b/008/L/NIR/008_L_NIR_5.tiff', '/host/b/008/L/NIR/008_L_NIR_10.tiff', '/host/b/008/L/NIR/008_L_NIR_12.tiff', '/host/b/008/L/NIR/008_L_NIR_1.tiff', '/host/b/008/L/NIR/008_L_NIR_13.tiff', '/host/b/008/L/NIR/008_L_NIR_7.tiff', '/host/b/008/L/NIR/008_L_NIR_11.tiff', '/host/b/008/L/NIR/008_L_NIR_9.tiff', '/host/b/008/L/NIR/008_L_NIR_15.tiff', '/host/b/008/L/VIS/008_L_VIS_5.tiff', '/host/b/008/L/VIS/008_L_VIS_8.tiff', '/host/b/008/L/VIS/008_L_VIS_13.tiff', '/host/b/008/L/VIS/008_L_VIS_4
# 008_R_VIS_6.png
# 008_R_VIS_12.png
# 008_R_VIS_1.png
# 008_R_VIS_3.png
# 008_R_VIS_13.png
# 008_R_VIS_15.png
# 008_R_VIS_2.png
# 008_R_VIS_14.png
# 008_R_VIS_5.png
# 008_R_VIS_4.png
# 008_R_VIS_8.png
# 008_R_VIS_9.png
# 008_R_VIS_10.png
# 008_R_VIS_11.png
# 100_L_NIR_11.png
# 100_L_NIR_8.png
# 100_L_NIR_10.png
# 100_L_NIR_2.png
# 100_L_NIR_12.png
# 100_L_NIR_9.png
# 100_L_NIR_13.png
# 100_L_NIR_14.png
# 100_L_NIR_3.png
# 100_L_NIR_1.png
# 100_L_NIR_4.png
# 100_L_NIR_15.png
# 100_L_NIR_7.png
# 100_L_NIR_5.png
# 100_L_NIR_6.png
# 100_L_VIS_1.png
# 100_L_VIS_11.png
# 100_L_VIS_3.png
# 100_L_VIS_2.png
# 100_L_VIS_13.png
# 100_L_VIS_8.png
# 100_L_VIS_9.png
# 100_L_VIS_10.png
# 100_L_VIS_14.png
# 100_L_VIS_12.png
# 100_L_VIS_7.png
# 100_L_VIS_15.png
# 100_L_VIS_4.png
# 100_L_VIS_5.png
# 100_L_VIS_6.png
# 100_R_NIR_12.png
# 100_R_NIR_6.png
# 100_R_NIR_11.png
# 100_R_NIR_13.png
# 100_R_NIR_4.png
# 100_R_NIR_1.png
# 100_R_NIR_5.png
# 100_R_NIR_15.png
# 100_R_NIR_8.png
# 100_R_NIR_9.png
# 100_R_NIR_10.png
# 100_R_NIR_3.png
# 100_R_NIR_7.png
# 100_R_NIR_2.png
# 100_R_NIR_14.png
# 100_R_VIS_7.png
# 100_R_VIS_3.png
# 100_R_VIS_2.png
# 100_R_VIS_13.png
# 100_R_VIS_14.png
# 100_R_VIS_9.png
# 100_R_VIS_5.png
# 100_R_VIS_10.png
# 100_R_VIS_15.png
# 100_R_VIS_4.png
# 100_R_VIS_11.png
# 100_R_VIS_6.png
# 100_R_VIS_12.png
# 100_R_VIS_1.png
# 100_R_VIS_8.png
# 031_L_NIR_8.png
# 031_L_NIR_10.png
# 031_L_NIR_15.png
# 031_L_NIR_7.png
# 031_L_NIR_14.png
# 031_L_NIR_11.png
# 031_L_NIR_5.png
# 031_L_NIR_2.png
# 031_L_NIR_4.png
# 031_L_NIR_9.png
# 031_L_NIR_1.png
# 031_L_NIR_12.png
# 031_L_NIR_3.png
# 031_L_NIR_13.png
# 031_L_NIR_6.png
# 031_L_VIS_15.png
# 031_L_VIS_3.png
# 031_L_VIS_2.png
# 031_L_VIS_1.png
# 031_L_VIS_13.png
# 031_L_VIS_12.png
# 031_L_VIS_6.png
# 031_L_VIS_10.png
# 031_L_VIS_7.png
# 031_L_VIS_8.png
# 031_L_VIS_14.png
# 031_L_VIS_11.png
# 031_L_VIS_5.png
# 031_L_VIS_9.png
# 031_L_VIS_4.png
# 031_R_NIR_12.png
# 031_R_NIR_6.png
# 031_R_NIR_8.png
# 031_R_NIR_13.png
# 158_L_VIS_11.png
# 158_L_VIS_14.png
# 158_L_VIS_8.png
# 158_L_VIS_7.png
# 158_L_VIS_15.png
# 158_L_VIS_13.png
# 158_L_VIS_9.png
# 158_R_NIR_14.png
# 158_R_NIR_5.png
# 158_R_NIR_6.png
# 158_R_NIR_11.png
# 158_R_NIR_9.png
# 158_R_NIR_3.png
# 158_R_NIR_4.png
# 158_R_NIR_15.png
# 158_R_NIR_7.png
# 158_R_NIR_2.png
# 158_R_NIR_10.png
# 158_R_NIR_12.png
# 158_R_NIR_8.png
# 158_R_NIR_1.png
# 158_R_NIR_13.png
# 158_R_VIS_3.png
# 158_R_VIS_1.png
# 158_R_VIS_4.png
# 158_R_VIS_13.png
# 158_R_VIS_8.png
# 158_R_VIS_15.png
# 158_R_VIS_14.png
# 158_R_VIS_12.png
# 158_R_VIS_7.png
# 158_R_VIS_6.png
# 158_R_VIS_11.png
# 158_R_VIS_10.png
# 158_R_VIS_9.png
# 158_R_VIS_2.png
# 158_R_VIS_5.png
# 206_L_NIR_6.png
# 206_L_NIR_3.png
# 206_L_NIR_12.png
# 206_L_NIR_14.png
# 206_L_NIR_8.png
# 206_L_NIR_10.png
# 206_L_NIR_13.png
# 206_L_NIR_5.png
# 206_L_NIR_11.png
# 206_L_NIR_15.png
# 206_L_NIR_7.png
# 206_L_NIR_9.png
# 206_L_NIR_2.png
# 206_L_NIR_4.png
# 206_L_NIR_1.png
# 206_L_VIS_3.png
# 206_L_VIS_6.png
# 206_L_VIS_10.png
# 206_L_VIS_12.png
# 206_L_VIS_13.png
# 206_L_VIS_9.png
# 206_L_VIS_14.png
# 206_L_VIS_8.png
# 206_L_VIS_2.png
# 206_L_VIS_11.png
# 206_L_VIS_7.png
# 206_L_VIS_5.png
# 206_L_VIS_1.png
# 206_L_VIS_4.png
# 206_L_VIS_15.png
# 206_R_NIR_12.png
# 206_R_NIR_4.png
# 206_R_NIR_13.png
# 206_R_NIR_6.png
# 206_R_NIR_15.png
# 206_R_NIR_14.png
# 206_R_NIR_9.png
# 206_R_NIR_11.png
# 206_R_NIR_3.png
# 206_R_NIR_1.png
# 206_R_NIR_2.png
# 206_R_NIR_5.png
# 206_R_NIR_8.png
# 206_R_NIR_10.png
# 206_R_NIR_7.png
# 206_R_VIS_12.png
# 206_R_VIS_14.png
# 206_R_VIS_3.png
# 206_R_VIS_2.png
# 206_R_VIS_9.png
# 206_R_VIS_10.png
# 206_R_VIS_15.png
# 206_R_VIS_8.png
# 206_R_VIS_1.png
# 206_R_VIS_6.png
# 206_R_VIS_13.png
# 206_R_VIS_5.png
# 206_R_VIS_11.png
# 206_R_VIS_4.png
# 206_R_VIS_7.png
# 204_L_NIR_15.png
# 204_L_NIR_5.png
# 204_L_NIR_2.png
# 204_L_NIR_3.png
# 204_L_NIR_1.png
# 204_L_NIR_13.png
# 204_L_NIR_6.png
# 204_L_NIR_9.png
# 204_L_NIR_11.png
# 204_L_NIR_4.png
# 204_L_NIR_10.png
# 204_L_NIR_7.png
# 082_R_NIR_4.png
# 082_R_NIR_2.png
# 082_R_NIR_8.png
# 082_R_NIR_11.png
# 082_R_NIR_9.png
# 082_R_NIR_3.png
# 082_R_NIR_15.png
# 082_R_NIR_7.png
# 082_R_VIS_14.png
# 082_R_VIS_15.png
# 082_R_VIS_9.png
# 082_R_VIS_1.png
# 082_R_VIS_2.png
# 082_R_VIS_5.png
# 082_R_VIS_13.png
# 082_R_VIS_3.png
# 082_R_VIS_11.png
# 082_R_VIS_8.png
# 082_R_VIS_6.png
# 082_R_VIS_7.png
# 082_R_VIS_4.png
# 082_R_VIS_10.png
# 082_R_VIS_12.png
# 165_L_NIR_15.png
# 165_L_NIR_7.png
# 165_L_NIR_14.png
# 165_L_NIR_3.png
# 165_L_NIR_12.png
# 165_L_NIR_2.png
# 165_L_NIR_6.png
# 165_L_NIR_4.png
# 165_L_NIR_11.png
# 165_L_NIR_8.png
# 165_L_NIR_5.png
# 165_L_NIR_1.png
# 165_L_NIR_13.png
# 165_L_NIR_10.png
# 165_L_NIR_9.png
# 165_L_VIS_8.png
# 165_L_VIS_11.png
# 165_L_VIS_7.png
# 165_L_VIS_15.png
# 165_L_VIS_10.png
# 165_L_VIS_13.png
# 165_L_VIS_2.png
# 165_L_VIS_6.png
# 165_L_VIS_9.png
# 165_L_VIS_12.png
# 165_L_VIS_4.png
# 165_L_VIS_1.png
# 165_L_VIS_14.png
# 165_L_VIS_5.png
# 165_L_VIS_3.png
# 165_R_NIR_13.png
# 165_R_NIR_12.png
# 165_R_NIR_4.png
# 165_R_NIR_2.png
# 165_R_NIR_5.png
# 165_R_NIR_14.png
# 165_R_NIR_3.png
# 165_R_NIR_11.png
# 165_R_NIR_7.png
# 165_R_NIR_10.png
# 165_R_NIR_6.png
# 165_R_NIR_8.png
# 165_R_NIR_15.png
# 165_R_NIR_1.png
# 165_R_NIR_9.png
# 165_R_VIS_3.png
# 165_R_VIS_15.png
# 165_R_VIS_8.png
# 165_R_VIS_14.png
# 165_R_VIS_13.png
# 165_R_VIS_2.png
# 165_R_VIS_6.png
# 165_R_VIS_9.png
# 165_R_VIS_11.png
# 165_R_VIS_7.png
# 165_R_VIS_12.png
# 165_R_VIS_10.png
# 165_R_VIS_4.png
# 165_R_VIS_5.png
# 165_R_VIS_1.png
# 020_L_NIR_15.png
# 020_L_NIR_12.png
# 020_L_NIR_1.png
# 020_L_NIR_11.png
# 020_L_NIR_6.png
# 020_L_NIR_10.png
# 020_L_NIR_4.png
# 020_L_NIR_13.png
# 020_L_NIR_3.png
# 020_L_NIR_8.png
# 020_L_NIR_9.png
# 020_L_NIR_5.png
# 020_L_NIR_2.png
# 020_L_NIR_14.png
# 020_L_NIR_7.png
# 020_L_VIS_14.png
# 020_L_VIS_1.png
# 020_L_VIS_13.png
# 020_L_VIS_3.png
# 020_L_VIS_15.png
# 020_L_VIS_5.png
# 020_L_VIS_9.png
# 020_L_VIS_10.png
# 020_L_VIS_2.png
# 020_L_VIS_12.png
# 020_L_VIS_7.png
# 020_L_VIS_8.png
# 020_L_VIS_11.png
# 020_L_VIS_4.png
# 020_L_VIS_6.png
# 020_R_NIR_15.png
# 020_R_NIR_3.png
# 020_R_NIR_11.png
# 020_R_NIR_5.png
# 020_R_NIR_7.png
# 020_R_NIR_2.png
# 020_R_NIR_9.png
# 020_R_NIR_6.png
# 020_R_NIR_14.png
# 020_R_NIR_1.png
# 020_R_NIR_4.png
# 020_R_NIR_13.png
# 020_R_NIR_12.png
# 020_R_NIR_8.png
# 020_R_NIR_10.png
# 020_R_VIS_4.png
# 020_R_VIS_2.png
# 020_R_VIS_12.png
# 020_R_VIS_8.png
# 020_R_VIS_6.png
# 020_R_VIS_9.png
# 020_R_VIS_1.png
# 020_R_VIS_15.png
# 020_R_VIS_11.png
# 020_R_VIS_3.png
# 020_R_VIS_10.png
# 020_R_VIS_7.png
# 020_R_VIS_5.png
# 020_R_VIS_14.png
# 020_R_VIS_13.png
# 078_L_NIR_7.png
# 078_L_NIR_3.png
# 078_L_NIR_14.png
# 078_L_NIR_13.png
# 078_L_NIR_5.png
# 078_L_NIR_9.png
# 078_L_NIR_8.png
# 078_L_NIR_11.png
# 078_L_NIR_10.png
# 078_L_NIR_1.png
# 078_L_NIR_15.png
# 078_L_NIR_2.png
# 078_L_NIR_6.png
# 078_L_NIR_12.png
# 078_L_NIR_4.png
# 078_L_VIS_9.png
# 078_L_VIS_11.png
# 078_L_VIS_15.png
# 078_L_VIS_1.png
# 078_L_VIS_13.png
# 078_L_VIS_4.png
# 078_L_VIS_7.png
# 078_L_VIS_10.png
# 078_L_VIS_12.png
# 078_L_VIS_6.png
# 078_L_VIS_3.png
# 078_L_VIS_8.png
# 078_L_VIS_2.png
# 078_L_VIS_5.png
# 078_L_VIS_14.png
# 078_R_NIR_14.png
# 078_R_NIR_5.png
# 078_R_NIR_11.png
# 078_R_NIR_3.png
# 078_R_NIR_8.png
# 078_R_NIR_2.png
# 078_R_NIR_1.png
# 078_R_NIR_10.png
# 078_R_NIR_4.png
# 078_R_NIR_7.png
# 078_R_NIR_13.png
# 078_R_NIR_9.png
# 078_R_NIR_6.png
# 078_R_NIR_15.png
# 078_R_NIR_12.png
# 078_R_VIS_2.png
# 078_R_VIS_10.png
# 078_R_VIS_12.png
# 078_R_VIS_4.png
# 078_R_VIS_15.png
# 078_R_VIS_13.png
# 078_R_VIS_9.png
# 078_R_VIS_7.png
# 078_R_VIS_3.png
# 078_R_VIS_6.png
# 078_R_VIS_8.png
# 078_R_VIS_14.png
# 078_R_VIS_5.png
# 078_R_VIS_1.png
# 078_R_VIS_11.png
# 079_L_NIR_7.png
# 079_L_NIR_6.png
# 079_L_NIR_10.png
# 079_L_NIR_5.png
# 079_L_NIR_11.png
# 079_L_NIR_12.png
# 079_L_NIR_13.png
# 079_L_NIR_3.png
# 079_L_NIR_15.png
# 079_L_NIR_1.png
# 079_L_NIR_14.png
# 079_L_NIR_9.png
# 079_L_NIR_4.png
# 079_L_NIR_8.png
# 079_L_NIR_2.png
# 205_L_NIR_5.png
# 205_L_NIR_2.png
# 205_L_NIR_11.png
# 205_L_NIR_12.png
# 205_L_NIR_6.png
# 205_L_NIR_1.png
# 205_L_NIR_3.png
# 205_L_NIR_8.png
# 205_L_NIR_4.png
# 205_L_NIR_7.png
# 205_L_NIR_10.png
# 205_L_NIR_13.png
# 205_L_VIS_13.png
# 205_L_VIS_14.png
# 205_L_VIS_15.png
# 205_L_VIS_3.png
# 205_L_VIS_6.png
# 205_L_VIS_5.png
# 205_L_VIS_7.png
# 205_L_VIS_9.png
# 205_L_VIS_1.png
# 205_L_VIS_10.png
# 205_L_VIS_2.png
# 205_L_VIS_8.png
# 205_L_VIS_12.png
# 205_L_VIS_11.png
# 205_L_VIS_4.png
# 205_R_NIR_15.png
# 205_R_NIR_11.png
# 205_R_NIR_2.png
# 205_R_NIR_3.png
# 205_R_NIR_7.png
# 205_R_NIR_12.png
# 205_R_NIR_9.png
# 205_R_NIR_10.png
# 205_R_NIR_14.png
# 205_R_NIR_13.png
# 205_R_NIR_5.png
# 205_R_NIR_8.png
# 205_R_NIR_1.png
# 205_R_NIR_4.png
# 205_R_NIR_6.png
# 205_R_VIS_11.png
# 205_R_VIS_14.png
# 205_R_VIS_13.png
# 205_R_VIS_8.png
# 205_R_VIS_9.png
# 205_R_VIS_15.png
# 205_R_VIS_1.png
# 205_R_VIS_7.png
# 205_R_VIS_3.png
# 205_R_VIS_12.png
# 205_R_VIS_5.png
# 205_R_VIS_10.png
# 205_R_VIS_4.png
# 205_R_VIS_2.png
# 205_R_VIS_6.png
# 038_L_NIR_8.png
# 038_L_NIR_13.png
# 038_L_NIR_1.png
# 038_L_NIR_5.png
# 038_L_NIR_7.png
# 038_L_NIR_14.png
# 038_L_NIR_15.png
# 038_L_NIR_4.png
# 038_L_NIR_10.png
# 038_L_NIR_6.png
# 038_L_NIR_3.png
# 038_L_NIR_12.png
# 038_L_NIR_11.png
# 038_L_NIR_2.png
# 038_L_NIR_9.png
# 038_L_VIS_1.png
# 038_L_VIS_11.png
# 038_L_VIS_3.png
# 038_L_VIS_10.png
# 038_L_VIS_8.png
# 038_L_VIS_15.png
# 038_L_VIS_5.png
# 038_L_VIS_4.png
# 038_L_VIS_13.png
# 038_L_VIS_6.png
# 038_L_VIS_14.png
# 038_L_VIS_7.png
# 038_L_VIS_9.png
# 038_L_VIS_2.png
# 038_L_VIS_12.png
# 038_R_NIR_3.png
# 038_R_NIR_9.png
# 038_R_NIR_8.png
# 038_R_NIR_11.png
# 038_R_NIR_1.png
# 038_R_NIR_14.png
# 038_R_NIR_5.png
# 038_R_NIR_7.png
# 038_R_NIR_12.png
# 038_R_NIR_10.png
# 038_R_NIR_15.png
# 038_R_NIR_13.png
# 038_R_NIR_6.png
# 038_R_NIR_2.png
# 038_R_NIR_4.png
# 038_R_VIS_4.png
# 038_R_VIS_10.png
# 038_R_VIS_3.png
# 038_R_VIS_11.png
# 038_R_VIS_14.png
# 038_R_VIS_7.png
# 038_R_VIS_8.png
# 072_L_VIS_8.png
# 072_R_NIR_7.png
# 072_R_NIR_11.png
# 072_R_NIR_8.png
# 072_R_NIR_1.png
# 072_R_NIR_4.png
# 072_R_NIR_15.png
# 072_R_NIR_10.png
# 072_R_NIR_13.png
# 072_R_NIR_3.png
# 072_R_NIR_5.png
# 072_R_NIR_12.png
# 072_R_NIR_6.png
# 072_R_NIR_9.png
# 072_R_NIR_2.png
# 072_R_NIR_14.png
# 072_R_VIS_6.png
# 072_R_VIS_2.png
# 072_R_VIS_4.png
# 072_R_VIS_14.png
# 072_R_VIS_8.png
# 072_R_VIS_10.png
# 072_R_VIS_13.png
# 072_R_VIS_7.png
# 072_R_VIS_1.png
# 072_R_VIS_15.png
# 072_R_VIS_12.png
# 072_R_VIS_3.png
# 072_R_VIS_9.png
# 072_R_VIS_11.png
# 072_R_VIS_5.png
# 159_L_NIR_13.png
# 159_L_NIR_1.png
# 159_L_NIR_5.png
# 159_L_NIR_8.png
# 159_L_NIR_9.png
# 159_L_NIR_15.png
# 159_L_NIR_12.png
# 159_L_NIR_10.png
# 159_L_NIR_7.png
# 159_L_NIR_4.png
# 159_L_NIR_3.png
# 159_L_NIR_2.png
# 159_L_NIR_11.png
# 159_L_NIR_6.png
# 159_L_NIR_14.png
# 159_L_VIS_2.png
# 159_L_VIS_11.png
# 159_L_VIS_3.png
# 159_L_VIS_6.png
# 159_L_VIS_15.png
# 159_L_VIS_12.png
# 159_L_VIS_9.png
# 159_L_VIS_8.png
# 159_L_VIS_4.png
# 159_L_VIS_14.png
# 159_L_VIS_10.png
# 159_L_VIS_13.png
# 159_L_VIS_7.png
# 159_L_VIS_1.png
# 159_L_VIS_5.png
# 159_R_NIR_15.png
# 159_R_NIR_3.png
# 159_R_NIR_12.png
# 159_R_NIR_14.png
# 159_R_NIR_4.png
# 159_R_NIR_13.png
# 159_R_NIR_2.png
# 159_R_NIR_1.png
# 159_R_NIR_9.png
# 159_R_NIR_5.png
# 159_R_NIR_11.png
# 159_R_NIR_8.png
# 159_R_NIR_10.png
# 159_R_NIR_6.png
# 159_R_NIR_7.png
# 159_R_VIS_13.png
# 159_R_VIS_3.png
# 159_R_VIS_5.png
# 159_R_VIS_9.png
# 159_R_VIS_15.png
# 159_R_VIS_11.png
# 159_R_VIS_14.png
# 159_R_VIS_4.png
# 159_R_VIS_8.png
# 159_R_VIS_10.png
# 159_R_VIS_12.png
# 159_R_VIS_1.png
# 159_R_VIS_2.png
# 159_R_VIS_7.png
# 159_R_VIS_6.png
# 005_L_NIR_1.png
# 005_L_NIR_9.png
# 005_L_NIR_2.png
# 005_L_NIR_14.png
# 005_L_NIR_5.png
# 005_L_NIR_13.png
# 005_L_NIR_11.png
# 005_L_NIR_8.png
# 005_L_NIR_10.png
# 005_L_NIR_6.png
# 005_L_NIR_4.png
# 005_L_NIR_12.png
# 005_L_NIR_7.png
# 005_L_NIR_15.png
# 005_L_NIR_3.png
# 005_L_VIS_10.png
# 005_L_VIS_14.png
# 005_L_VIS_5.png
# 005_L_VIS_4.png
# 005_L_VIS_12.png
# 005_L_VIS_9.png
# 005_L_VIS_8.png
# 005_L_VIS_1.png
# 005_L_VIS_2.png
# 005_L_VIS_11.png
# 005_L_VIS_3.png
# 005_L_VIS_7.png
# 005_L_VIS_6.png
# 005_L_VIS_13.png
# 005_L_VIS_15.png
# 005_R_NIR_11.png
# 005_R_NIR_14.png
# 005_R_NIR_9.png
# 005_R_NIR_4.png
# 005_R_NIR_10.png
# 005_R_NIR_5.png
# 005_R_NIR_13.png
# 005_R_NIR_2.png
# 005_R_NIR_6.png
# 005_R_NIR_8.png
# 005_R_NIR_7.png
# 005_R_NIR_15.png
# 005_R_NIR_1.png
# 005_R_NIR_3.png
# 005_R_NIR_12.png
# 005_R_VIS_11.png
# 005_R_VIS_1.png
# 005_R_VIS_10.png
# 005_R_VIS_3.png
# 005_R_VIS_6.png
# 005_R_VIS_2.png
# 005_R_VIS_8.png
# 005_R_VIS_14.png
# 005_R_VIS_13.png
# 005_R_VIS_15.png
# 005_R_VIS_7.png
# 005_R_VIS_12.png
# 005_R_VIS_5.png
# 005_R_VIS_9.png
# 005_R_VIS_4.png
# 121_L_NIR_2.png
# 121_L_NIR_4.png
# 121_L_NIR_13.png
# 121_L_NIR_9.png
# 121_L_NIR_11.png
# 121_L_NIR_14.png
# 121_L_NIR_6.png
# 121_L_NIR_10.png
# 121_L_NIR_3.png
# 121_L_NIR_8.png
# 121_L_NIR_5.png
# 121_L_NIR_12.png
# 121_L_NIR_7.png
# 121_L_NIR_15.png
# 121_L_NIR_1.png
# 121_L_VIS_3.png
# 121_L_VIS_8.png
# 121_L_VIS_14.png
# 121_L_VIS_11.png
# 121_L_VIS_4.png
# 121_L_VIS_15.png
# 121_L_VIS_7.png
# 121_L_VIS_10.png
# 121_L_VIS_12.png
# 121_L_VIS_6.png
# 121_L_VIS_1.png
# 121_L_VIS_13.png
# 121_L_VIS_2.png
# 121_L_VIS_9.png
# 121_L_VIS_5.png
# 121_R_NIR_12.png
# 121_R_NIR_15.png
# 121_R_NIR_13.png
# 121_R_NIR_6.png
# 121_R_NIR_14.png
# 121_R_NIR_9.png
# 121_R_NIR_2.png
# 121_R_NIR_4.png
# 121_R_NIR_10.png
# 121_R_NIR_7.png
# 121_R_NIR_5.png
# 121_R_NIR_8.png
# 121_R_NIR_1.png
# 121_R_NIR_3.png
# 121_R_NIR_11.png
# 121_R_VIS_12.png
# 121_R_VIS_9.png
# 121_R_VIS_7.png
# 121_R_VIS_11.png
# 121_R_VIS_1.png
# 121_R_VIS_10.png
# 121_R_VIS_15.png
# 121_R_VIS_4.png
# 121_R_VIS_8.png
# 121_R_VIS_2.png
# 121_R_VIS_6.png
# 121_R_VIS_14.png
# 121_R_VIS_13.png
# 121_R_VIS_3.png
# 121_R_VIS_5.png
# 054_L_NIR_6.png
# 054_L_NIR_5.png
# 054_L_NIR_1.png
# 054_L_NIR_2.png
# 054_L_NIR_8.png
# 054_L_NIR_14.png
